# %%
import pandas as pd
import numpy as np
import re

# Load the processed data from previous notebook
df = pd.read_csv('../../data/raw/Retail_Sales_Data.csv' )

# Quick inspection
print(df.head())
print(df.info())
# Out:
#   retailer  store_id  week                   product  \
# 0  retail1         1     1       MintyFresh Mint 18g
# 1  retail1         1     1    ChocoDelight Dark 200g
# 2  retail1         1     1   ChocoDelight White 350g
# 3  retail1         1     1  NuttyCream Hazelnuts 80g
# 4  retail1         1     1        DarkDream Dark 60g
#
#                                          description  regular_price  \
# 0                    MintyFresh refresh mint 18grams      10.308645
# 1                           200g ChocoDelight smooth       7.947956
# 2                        350g ChocoDelight delicious      13.439368
# 3                delightful Hazelnuts 80g NuttyCream       5.112777
# 4  A decadent DarkDream dark chocolate ice cream ...      14.085425
#
#    competition_1_regular_price  competition_2_regular_price  \
# 0                    10.624815                    10.013451
# 1                     7.748726                     7.589198
# 2                    13.751508                    13.183621
# 3                     5.279713                     5.222118
# 4                    14.153721                    13.860002
#
#    competition_3_regular_price  competition_4_regular_price  ...  \
# 0                    10.378847                     9.910385  ...
# 1                     8.085262                     7.602363  ...
# 2                    13.875440                    12.982707  ...
# 3                     5.117789                     4.877549  ...
# 4                    14.339698                    14.365517  ...
#
#    competition_4_promo_price  competition_5_promo_price  \
# 0                   8.500521                   7.139537
# 1                   5.766135                   4.267236
# 2                   8.195118                   8.214548
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    competition_6_promo_price  competition_7_promo_price  \
# 0                   7.606831                   8.339536
# 1                   5.912718                   5.156558
# 2                   8.995387                  10.266603
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    competition_8_promo_price  competition_9_promo_price  \
# 0                   7.184384                   5.759620
# 1                   6.976287                   5.884786
# 2                  10.940801                   8.727031
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    competition_10_promo_price      value    volume   quantity
# 0                    7.376553  85.368310  3.953882   9.707949
# 1                    5.335849  82.924731  2.991418  14.922586
# 2                    7.915147  52.527762  6.513600  12.889607
# 3                         NaN  48.373782  5.489587  14.374834
# 4                         NaN  47.718252  9.152050   9.193818
#
# [5 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8840 entries, 0 to 8839
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   retailer                      8840 non-null   object
#  1   store_id                      8840 non-null   int64
#  2   week                          8840 non-null   int64
#  3   product                       8840 non-null   object
#  4   description                   8840 non-null   object
#  5   regular_price                 8840 non-null   float64
#  6   competition_1_regular_price   8840 non-null   float64
#  7   competition_2_regular_price   8840 non-null   float64
#  8   competition_3_regular_price   8840 non-null   float64
#  9   competition_4_regular_price   8840 non-null   float64
#  10  competition_5_regular_price   8840 non-null   float64
#  11  competition_6_regular_price   8840 non-null   float64
#  12  competition_7_regular_price   8840 non-null   float64
#  13  competition_8_regular_price   8840 non-null   float64
#  14  competition_9_regular_price   8840 non-null   float64
#  15  competition_10_regular_price  8840 non-null   float64
#  16  promo_price                   646 non-null    float64
#  17  competition_1_promo_price     646 non-null    float64
#  18  competition_2_promo_price     646 non-null    float64
#  19  competition_3_promo_price     646 non-null    float64
#  20  competition_4_promo_price     646 non-null    float64
#  21  competition_5_promo_price     646 non-null    float64
#  22  competition_6_promo_price     646 non-null    float64
#  23  competition_7_promo_price     646 non-null    float64
#  24  competition_8_promo_price     646 non-null    float64
#  25  competition_9_promo_price     646 non-null    float64
#  26  competition_10_promo_price    646 non-null    float64
#  27  value                         8840 non-null   float64
#  28  volume                        8840 non-null   float64
#  29  quantity                      8840 non-null   float64
# dtypes: float64(25), int64(2), object(3)
# memory usage: 2.0+ MB
# None

# %%
product_info_df = df[['description', 'product']].copy()

# %%
# Print the first 10 descriptions and their corresponding product names
for i in range(10):
    description = df.loc[i, 'description']
    product = df.loc[i, 'product']
    print(f"Example {i + 1}:")
    print(f"Description: {description}")
    print(f"Product: {product}")
    print("-----------")
# Out:
# Example 1:
# Description: MintyFresh refresh mint 18grams
# Product: MintyFresh Mint 18g
# -----------
# Example 2:
# Description: 200g ChocoDelight smooth
# Product: ChocoDelight Dark 200g
# -----------
# Example 3:
# Description: 350g ChocoDelight delicious
# Product: ChocoDelight White 350g
# -----------
# Example 4:
# Description: delightful Hazelnuts 80g NuttyCream
# Product: NuttyCream Hazelnuts 80g
# -----------
# Example 5:
# Description: A decadent DarkDream dark chocolate ice cream with a weight of 60 grams.
# Product: DarkDream Dark 60g
# -----------
# Example 6:
# Description: MintyFresh refresh mint 18grams
# Product: MintyFresh Mint 18g
# -----------
# Example 7:
# Description: A rich and smooth ChocoDelight dark chocolate bar weighing (150+50) 200 grams.
# Product: ChocoDelight Dark 200g
# -----------
# Example 8:
# Description: ChocoDelight White 350g creamy
# Product: ChocoDelight White 350g
# -----------
# Example 9:
# Description: Hazelnuts NuttyCream 80g  delightful
# Product: NuttyCream Hazelnuts 80g
# -----------
# Example 10:
# Description: A decadent DarkDream dark chocolate ice cream with a weight of 60 grams.
# Product: DarkDream Dark 60g
# -----------

# %% [markdown]
# ### LLM Implementation with Haiku

# %%
import anthropic
import time
import pandas as pd

ANTHROPIC_API_KEY = "YOUR_API_KEY"

# Few-shot examples to guide Claude
few_shot_examples = """
Example 1:
Description: MintyFresh refresh mint 18grams
Product: MintyFresh Mint 18g
-----------

Example 2:
Description: 200g ChocoDelight smooth
Product: ChocoDelight Dark 200g
-----------

Example 3:
Description: 350g ChocoDelight delicious
Product: ChocoDelight White 350g
-----------

Example 4:
Description: delightful Hazelnuts 80g NuttyCream
Product: NuttyCream Hazelnuts 80g
-----------

Example 5:
Description: A decadent DarkDream dark chocolate ice cream with a weight of 60 grams.
Product: DarkDream Dark 60g
-----------

Example 6:
Description: MintyFresh refresh mint 18grams
Product: MintyFresh Mint 18g
-----------

Example 7:
Description: A rich and smooth ChocoDelight dark chocolate bar weighing (150+50) 200 grams.
Product: ChocoDelight Dark 200g
-----------

Example 8:
Description: ChocoDelight White 350g creamy
Product: ChocoDelight White 350g
-----------

Example 9:
Description: Hazelnuts NuttyCream 80g delightful
Product: NuttyCream Hazelnuts 80g
-----------

Example 10:
Description: A decadent DarkDream dark chocolate ice cream with a weight of 60 grams.
Product: DarkDream Dark 60g
"""

def claude_extract_product_info(df, model="claude-3-haiku-20240307"):
    info_df = df[['description']].copy()
    
    # Add a column for the extracted Product information
    info_df['Product'] = None

    # Initialize Anthropic client
    client = anthropic.Client(api_key=ANTHROPIC_API_KEY)

    # Loop through descriptions and extract information
    for i, desc in enumerate(info_df['description']):
        prompt = prompt = f"""
                        {few_shot_examples}

                        For the following description, extract only the brand, product type, and weight. Avoid descriptors like "delicious," "tasty," or any adjective unrelated to the flavour or type (such as "mint," "dark," "white," or "hazelnut"). Format the response as shown in the examples without adding "Product:" or any explanation.

                        Description: "{desc}"

                        Return in this exact format:
                        "[Brand] [Type or Flavour] [Weight]"
                        """

        
        try:
            # Create message request to Claude
            response = client.messages.create(
                model=model,
                messages=[
                    {"role": "user", "content": prompt},
                    {"role": "assistant", "content": ""}
                ],
                stop_sequences=["-----------"],
                max_tokens=100,
                temperature=0
            )
            
            # Get response text
            product_text = response.content[0].text
            print(f"Processed Product for Description {i}: \n{product_text}\n")

            # Store the product name in the Product column
            info_df.at[i, 'Product'] = product_text

            # Add delay to avoid rate limit issues
            time.sleep(1.3)

        except Exception as e:
            print(f"Error processing description at index {i}: {e}")
            continue

    return info_df

# Run the function
extracted_info_df = claude_extract_product_info(df[:1000])
print(extracted_info_df.head())
# Out:
# Processed Product for Description 0:
# MintyFresh Mint 18g
#
# Processed Product for Description 1:
# ChocoDelight Dark 200g
#
# Processed Product for Description 2:
# ChocoDelight Dark 350g
#
# Processed Product for Description 3:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 4:
# DarkDream Dark 60g
#
# Processed Product for Description 5:
# MintyFresh Mint 18g
#
# Processed Product for Description 6:
# ChocoDelight Dark 200g
#
# Processed Product for Description 7:
# ChocoDelight White 350g
#
# Processed Product for Description 8:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 9:
# DarkDream Dark 60g
#
# Processed Product for Description 10:
# MintyFresh Mint 18g
#
# Processed Product for Description 11:
# ChocoDelight Dark 200g
#
# Processed Product for Description 12:
# ChocoDelight 350g
#
# Processed Product for Description 13:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 14:
# DarkDream Dark 60g
#
# Processed Product for Description 15:
# MintyFresh Mint 18g
#
# Processed Product for Description 16:
# ChocoDelight Dark 200g
#
# Processed Product for Description 17:
# ChocoDelight Dark 350g
#
# Processed Product for Description 18:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 19:
# DarkDream Dark 60g
#
# Processed Product for Description 20:
# MintyFresh Mint 18g
#
# Processed Product for Description 21:
# ChocoDelight Dark 200g
#
# Processed Product for Description 22:
# ChocoDelight Dark 350g
#
# Processed Product for Description 23:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 24:
# DarkDream Dark 60g
#
# Processed Product for Description 25:
# MintyFresh Mint 18g
#
# Processed Product for Description 26:
# ChocoDelight Dark 200g
#
# Processed Product for Description 27:
# ChocoDelight White 350g
#
# Processed Product for Description 28:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 29:
# DarkDream Dark 60g
#
# Processed Product for Description 30:
# MintyFresh Mint 18g
#
# Processed Product for Description 31:
# ChocoDelight Dark 200g
#
# Processed Product for Description 32:
# ChocoDelight 350g
#
# Processed Product for Description 33:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 34:
# DarkDream Dark 60g
#
# Processed Product for Description 35:
# MintyFresh Mint 18g
#
# Processed Product for Description 36:
# ChocoDelight Dark 200g
#
# Processed Product for Description 37:
# ChocoDelight White 350g
#
# Processed Product for Description 38:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 39:
# DarkDream Dark 60g
#
# Processed Product for Description 40:
# MintyFresh Mint 18g
#
# Processed Product for Description 41:
# ChocoDelight Dark 200g
#
# Processed Product for Description 42:
# ChocoDelight Dark 350g
#
# Processed Product for Description 43:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 44:
# DarkDream Dark 60g
#
# Processed Product for Description 45:
# MintyFresh Mint 18g
#
# Processed Product for Description 46:
# ChocoDelight Dark 200g
#
# Processed Product for Description 47:
# ChocoDelight White 350g
#
# Processed Product for Description 48:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 49:
# DarkDream Dark 60g
#
# Processed Product for Description 50:
# MintyFresh Mint 18g
#
# Processed Product for Description 51:
# ChocoDelight Dark 200g
#
# Processed Product for Description 52:
# ChocoDelight White 350g
#
# Processed Product for Description 53:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 54:
# DarkDream Dark 60g
#
# Processed Product for Description 55:
# MintyFresh Mint 18g
#
# Processed Product for Description 56:
# ChocoDelight Dark 200g
#
# Processed Product for Description 57:
# ChocoDelight Dark 350g
#
# Processed Product for Description 58:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 59:
# DarkDream Dark 60g
#
# Processed Product for Description 60:
# MintyFresh Mint 18g
#
# Processed Product for Description 61:
# ChocoDelight Dark 200g
#
# Processed Product for Description 62:
# ChocoDelight White 350g
#
# Processed Product for Description 63:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 64:
# DarkDream Dark 60g
#
# Processed Product for Description 65:
# MintyFresh Mint 18g
#
# Processed Product for Description 66:
# ChocoDelight Dark 200g
#
# Processed Product for Description 67:
# ChocoDelight White 350g
#
# Processed Product for Description 68:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 69:
# DarkDream Dark 60g
#
# Processed Product for Description 70:
# MintyFresh Mint 18g
#
# Processed Product for Description 71:
# ChocoDelight Dark 200g
#
# Processed Product for Description 72:
# ChocoDelight White 350g
#
# Processed Product for Description 73:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 74:
# DarkDream Dark 60g
#
# Processed Product for Description 75:
# MintyFresh Mint 18g
#
# Processed Product for Description 76:
# ChocoDelight Dark 200g
#
# Processed Product for Description 77:
# ChocoDelight 350g
#
# Processed Product for Description 78:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 79:
# DarkDream Dark 60g
#
# Processed Product for Description 80:
# MintyFresh Mint 18g
#
# Processed Product for Description 81:
# ChocoDelight Dark 200g
#
# Processed Product for Description 82:
# ChocoDelight 350g
#
# Processed Product for Description 83:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 84:
# DarkDream Dark 60g
#
# Processed Product for Description 85:
# MintyFresh Mint 18g
#
# Processed Product for Description 86:
# ChocoDelight Dark 200g
#
# Processed Product for Description 87:
# ChocoDelight White 350g
#
# Processed Product for Description 88:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 89:
# DarkDream Dark 60g
#
# Processed Product for Description 90:
# MintyFresh Mint 18g
#
# Processed Product for Description 91:
# ChocoDelight Dark 200g
#
# Processed Product for Description 92:
# ChocoDelight 350g
#
# Processed Product for Description 93:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 94:
# DarkDream Dark 60g
#
# Processed Product for Description 95:
# MintyFresh Mint 18g
#
# Processed Product for Description 96:
# ChocoDelight Dark 200g
#
# Processed Product for Description 97:
# ChocoDelight Dark 350g
#
# Processed Product for Description 98:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 99:
# DarkDream Dark 60g
#
# Processed Product for Description 100:
# MintyFresh Mint 18g
#
# Processed Product for Description 101:
# ChocoDelight Dark 200g
#
# Processed Product for Description 102:
# ChocoDelight White 350g
#
# Processed Product for Description 103:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 104:
# DarkDream Dark 60g
#
# Processed Product for Description 105:
# MintyFresh Mint 18g
#
# Processed Product for Description 106:
# ChocoDelight Dark 200g
#
# Processed Product for Description 107:
# ChocoDelight Dark 350g
#
# Processed Product for Description 108:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 109:
# DarkDream Dark 60g
#
# Processed Product for Description 110:
# MintyFresh Mint 18g
#
# Processed Product for Description 111:
# ChocoDelight Dark 200g
#
# Processed Product for Description 112:
# ChocoDelight Dark 350g
#
# Processed Product for Description 113:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 114:
# DarkDream Dark 60g
#
# Processed Product for Description 115:
# MintyFresh Mint 18g
#
# Processed Product for Description 116:
# ChocoDelight Dark 200g
#
# Processed Product for Description 117:
# ChocoDelight White 350g
#
# Processed Product for Description 118:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 119:
# DarkDream Dark 60g
#
# Processed Product for Description 120:
# MintyFresh Mint 18g
#
# Processed Product for Description 121:
# ChocoDelight Dark 200g
#
# Processed Product for Description 122:
# ChocoDelight 350g
#
# Processed Product for Description 123:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 124:
# DarkDream Dark 60g
#
# Processed Product for Description 125:
# MintyFresh Mint 18g
#
# Processed Product for Description 126:
# ChocoDelight Dark 200g
#
# Processed Product for Description 127:
# ChocoDelight Dark 350g
#
# Processed Product for Description 128:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 129:
# DarkDream Dark 60g
#
# Processed Product for Description 130:
# MintyFresh Mint 18g
#
# Processed Product for Description 131:
# ChocoDelight Dark 200g
#
# Processed Product for Description 132:
# ChocoDelight White 350g
#
# Processed Product for Description 133:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 134:
# DarkDream Dark 60g
#
# Processed Product for Description 135:
# MintyFresh Mint 18g
#
# Processed Product for Description 136:
# ChocoDelight Dark 200g
#
# Processed Product for Description 137:
# ChocoDelight White 350g
#
# Processed Product for Description 138:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 139:
# DarkDream Dark 60g
#
# Processed Product for Description 140:
# MintyFresh Mint 18g
#
# Processed Product for Description 141:
# ChocoDelight Dark 200g
#
# Processed Product for Description 142:
# ChocoDelight Dark 350g
#
# Processed Product for Description 143:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 144:
# DarkDream Dark 60g
#
# Processed Product for Description 145:
# MintyFresh Mint 18g
#
# Processed Product for Description 146:
# ChocoDelight Dark 200g
#
# Processed Product for Description 147:
# ChocoDelight White 350g
#
# Processed Product for Description 148:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 149:
# DarkDream Dark 60g
#
# Processed Product for Description 150:
# MintyFresh Mint 18g
#
# Processed Product for Description 151:
# ChocoDelight Dark 200g
#
# Processed Product for Description 152:
# ChocoDelight White 350g
#
# Processed Product for Description 153:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 154:
# DarkDream Dark 60g
#
# Processed Product for Description 155:
# MintyFresh Mint 18g
#
# Processed Product for Description 156:
# ChocoDelight Dark 200g
#
# Processed Product for Description 157:
# ChocoDelight White 350g
#
# Processed Product for Description 158:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 159:
# DarkDream Dark 60g
#
# Processed Product for Description 160:
# MintyFresh Mint 18g
#
# Processed Product for Description 161:
# ChocoDelight Dark 200g
#
# Processed Product for Description 162:
# ChocoDelight White 350g
#
# Processed Product for Description 163:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 164:
# DarkDream Dark 60g
#
# Processed Product for Description 165:
# MintyFresh Mint 18g
#
# Processed Product for Description 166:
# ChocoDelight Dark 200g
#
# Processed Product for Description 167:
# ChocoDelight White 350g
#
# Processed Product for Description 168:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 169:
# DarkDream Dark 60g
#
# Processed Product for Description 170:
# MintyFresh Mint 18g
#
# Processed Product for Description 171:
# ChocoDelight Dark 200g
#
# Processed Product for Description 172:
# ChocoDelight White 350g
#
# Processed Product for Description 173:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 174:
# DarkDream Dark 60g
#
# Processed Product for Description 175:
# MintyFresh Mint 18g
#
# Processed Product for Description 176:
# ChocoDelight Dark 200g
#
# Processed Product for Description 177:
# ChocoDelight Dark 350g
#
# Processed Product for Description 178:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 179:
# DarkDream Dark 60g
#
# Processed Product for Description 180:
# MintyFresh Mint 18g
#
# Processed Product for Description 181:
# ChocoDelight Dark 200g
#
# Processed Product for Description 182:
# ChocoDelight White 350g
#
# Processed Product for Description 183:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 184:
# DarkDream Dark 60g
#
# Processed Product for Description 185:
# MintyFresh Mint 18g
#
# Processed Product for Description 186:
# ChocoDelight Dark 200g
#
# Processed Product for Description 187:
# ChocoDelight 350g
#
# Processed Product for Description 188:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 189:
# DarkDream Dark 60g
#
# Processed Product for Description 190:
# MintyFresh Mint 18g
#
# Processed Product for Description 191:
# ChocoDelight Dark 200g
#
# Processed Product for Description 192:
# ChocoDelight Dark 350g
#
# Processed Product for Description 193:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 194:
# DarkDream Dark 60g
#
# Processed Product for Description 195:
# MintyFresh Mint 18g
#
# Processed Product for Description 196:
# ChocoDelight Dark 200g
#
# Processed Product for Description 197:
# ChocoDelight 350g
#
# Processed Product for Description 198:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 199:
# DarkDream Dark 60g
#
# Processed Product for Description 200:
# MintyFresh Mint 18g
#
# Processed Product for Description 201:
# ChocoDelight Dark 200g
#
# Processed Product for Description 202:
# ChocoDelight White 350g
#
# Processed Product for Description 203:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 204:
# DarkDream Dark 60g
#
# Processed Product for Description 205:
# MintyFresh Mint 18g
#
# Processed Product for Description 206:
# ChocoDelight Dark 200g
#
# Processed Product for Description 207:
# ChocoDelight 350g
#
# Processed Product for Description 208:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 209:
# DarkDream Dark 60g
#
# Processed Product for Description 210:
# MintyFresh Mint 18g
#
# Processed Product for Description 211:
# ChocoDelight Dark 200g
#
# Processed Product for Description 212:
# ChocoDelight 350g
#
# Processed Product for Description 213:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 214:
# DarkDream Dark 60g
#
# Processed Product for Description 215:
# MintyFresh Mint 18g
#
# Processed Product for Description 216:
# ChocoDelight Dark 200g
#
# Processed Product for Description 217:
# ChocoDelight 350g
#
# Processed Product for Description 218:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 219:
# DarkDream Dark 60g
#
# Processed Product for Description 220:
# MintyFresh Mint 18g
#
# Processed Product for Description 221:
# ChocoDelight Dark 200g
#
# Processed Product for Description 222:
# ChocoDelight 350g
#
# Processed Product for Description 223:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 224:
# DarkDream Dark 60g
#
# Processed Product for Description 225:
# MintyFresh Mint 18g
#
# Processed Product for Description 226:
# ChocoDelight Dark 200g
#
# Processed Product for Description 227:
# ChocoDelight Dark 350g
#
# Processed Product for Description 228:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 229:
# DarkDream Dark 60g
#
# Processed Product for Description 230:
# MintyFresh Mint 18g
#
# Processed Product for Description 231:
# ChocoDelight Dark 200g
#
# Processed Product for Description 232:
# ChocoDelight Dark 350g
#
# Processed Product for Description 233:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 234:
# DarkDream Dark 60g
#
# Processed Product for Description 235:
# MintyFresh Mint 18g
#
# Processed Product for Description 236:
# ChocoDelight Dark 200g
#
# Processed Product for Description 237:
# ChocoDelight Dark 350g
#
# Processed Product for Description 238:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 239:
# DarkDream Dark 60g
#
# Processed Product for Description 240:
# MintyFresh Mint 18g
#
# Processed Product for Description 241:
# ChocoDelight Dark 200g
#
# Processed Product for Description 242:
# ChocoDelight 350g
#
# Processed Product for Description 243:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 244:
# DarkDream Dark 60g
#
# Processed Product for Description 245:
# MintyFresh Mint 18g
#
# Processed Product for Description 246:
# ChocoDelight Dark 200g
#
# Processed Product for Description 247:
# ChocoDelight 350g
#
# Processed Product for Description 248:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 249:
# DarkDream Dark 60g
#
# Processed Product for Description 250:
# MintyFresh Mint 18g
#
# Processed Product for Description 251:
# ChocoDelight Dark 200g
#
# Processed Product for Description 252:
# ChocoDelight Dark 350g
#
# Processed Product for Description 253:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 254:
# DarkDream Dark 60g
#
# Processed Product for Description 255:
# MintyFresh Mint 18g
#
# Processed Product for Description 256:
# ChocoDelight Dark 200g
#
# Processed Product for Description 257:
# ChocoDelight 350g
#
# Processed Product for Description 258:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 259:
# DarkDream Dark 60g
#
# Processed Product for Description 260:
# MintyFresh Mint 18g
#
# Processed Product for Description 261:
# ChocoDelight Dark 200g
#
# Processed Product for Description 262:
# ChocoDelight 350g
#
# Processed Product for Description 263:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 264:
# DarkDream Dark 60g
#
# Processed Product for Description 265:
# MintyFresh Mint 18g
#
# Processed Product for Description 266:
# ChocoDelight Dark 200g
#
# Processed Product for Description 267:
# ChocoDelight White 350g
#
# Processed Product for Description 268:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 269:
# DarkDream Dark 60g
#
# Processed Product for Description 270:
# MintyFresh Mint 18g
#
# Processed Product for Description 271:
# ChocoDelight Dark 200g
#
# Processed Product for Description 272:
# ChocoDelight 350g
#
# Processed Product for Description 273:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 274:
# DarkDream Dark 60g
#
# Processed Product for Description 275:
# MintyFresh Mint 18g
#
# Processed Product for Description 276:
# ChocoDelight Dark 200g
#
# Processed Product for Description 277:
# ChocoDelight White 350g
#
# Processed Product for Description 278:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 279:
# DarkDream Dark 60g
#
# Processed Product for Description 280:
# MintyFresh Mint 18g
#
# Processed Product for Description 281:
# ChocoDelight Dark 200g
#
# Processed Product for Description 282:
# ChocoDelight 350g
#
# Processed Product for Description 283:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 284:
# DarkDream Dark 60g
#
# Processed Product for Description 285:
# MintyFresh Mint 18g
#
# Processed Product for Description 286:
# ChocoDelight Dark 200g
#
# Processed Product for Description 287:
# ChocoDelight Dark 350g
#
# Processed Product for Description 288:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 289:
# DarkDream Dark 60g
#
# Processed Product for Description 290:
# MintyFresh Mint 18g
#
# Processed Product for Description 291:
# ChocoDelight Dark 200g
#
# Processed Product for Description 292:
# ChocoDelight White 350g
#
# Processed Product for Description 293:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 294:
# DarkDream Dark 60g
#
# Processed Product for Description 295:
# MintyFresh Mint 18g
#
# Processed Product for Description 296:
# ChocoDelight Dark 200g
#
# Processed Product for Description 297:
# ChocoDelight White 350g
#
# Processed Product for Description 298:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 299:
# DarkDream Dark 60g
#
# Processed Product for Description 300:
# MintyFresh Mint 18g
#
# Processed Product for Description 301:
# ChocoDelight Dark 200g
#
# Processed Product for Description 302:
# ChocoDelight 350g
#
# Processed Product for Description 303:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 304:
# DarkDream Dark 60g
#
# Processed Product for Description 305:
# MintyFresh Mint 18g
#
# Processed Product for Description 306:
# ChocoDelight Dark 200g
#
# Processed Product for Description 307:
# ChocoDelight 350g
#
# Processed Product for Description 308:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 309:
# DarkDream Dark 60g
#
# Processed Product for Description 310:
# MintyFresh Mint 18g
#
# Processed Product for Description 311:
# ChocoDelight Dark 200g
#
# Processed Product for Description 312:
# ChocoDelight 350g
#
# Processed Product for Description 313:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 314:
# DarkDream Dark 60g
#
# Processed Product for Description 315:
# MintyFresh Mint 18g
#
# Processed Product for Description 316:
# ChocoDelight Dark 200g
#
# Processed Product for Description 317:
# ChocoDelight White 350g
#
# Processed Product for Description 318:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 319:
# DarkDream Dark 60g
#
# Processed Product for Description 320:
# MintyFresh Mint 18g
#
# Processed Product for Description 321:
# ChocoDelight Dark 200g
#
# Processed Product for Description 322:
# ChocoDelight White 350g
#
# Processed Product for Description 323:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 324:
# DarkDream Dark 60g
#
# Processed Product for Description 325:
# MintyFresh Mint 18g
#
# Processed Product for Description 326:
# ChocoDelight Dark 200g
#
# Processed Product for Description 327:
# ChocoDelight White 350g
#
# Processed Product for Description 328:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 329:
# DarkDream Dark 60g
#
# Processed Product for Description 330:
# MintyFresh Mint 18g
#
# Processed Product for Description 331:
# ChocoDelight Dark 200g
#
# Processed Product for Description 332:
# ChocoDelight Dark 350g
#
# Processed Product for Description 333:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 334:
# DarkDream Dark 60g
#
# Processed Product for Description 335:
# MintyFresh Mint 18g
#
# Processed Product for Description 336:
# ChocoDelight Dark 200g
#
# Processed Product for Description 337:
# ChocoDelight White 350g
#
# Processed Product for Description 338:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 339:
# DarkDream Dark 60g
#
# Processed Product for Description 340:
# MintyFresh Mint 18g
#
# Processed Product for Description 341:
# ChocoDelight Dark 200g
#
# Processed Product for Description 342:
# ChocoDelight 350g
#
# Processed Product for Description 343:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 344:
# DarkDream Dark 60g
#
# Processed Product for Description 345:
# MintyFresh Mint 18g
#
# Processed Product for Description 346:
# ChocoDelight Dark 200g
#
# Processed Product for Description 347:
# ChocoDelight 350g
#
# Processed Product for Description 348:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 349:
# DarkDream Dark 60g
#
# Processed Product for Description 350:
# MintyFresh Mint 18g
#
# Processed Product for Description 351:
# ChocoDelight Dark 200g
#
# Processed Product for Description 352:
# ChocoDelight White 350g
#
# Processed Product for Description 353:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 354:
# DarkDream Dark 60g
#
# Processed Product for Description 355:
# MintyFresh Mint 18g
#
# Processed Product for Description 356:
# ChocoDelight Dark 200g
#
# Processed Product for Description 357:
# ChocoDelight White 350g
#
# Processed Product for Description 358:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 359:
# DarkDream Dark 60g
#
# Processed Product for Description 360:
# MintyFresh Mint 18g
#
# Processed Product for Description 361:
# ChocoDelight Dark 200g
#
# Processed Product for Description 362:
# ChocoDelight 350g
#
# Processed Product for Description 363:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 364:
# DarkDream Dark 60g
#
# Processed Product for Description 365:
# MintyFresh Mint 18g
#
# Processed Product for Description 366:
# ChocoDelight Dark 200g
#
# Processed Product for Description 367:
# ChocoDelight White 350g
#
# Processed Product for Description 368:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 369:
# DarkDream Dark 60g
#
# Processed Product for Description 370:
# MintyFresh Mint 18g
#
# Processed Product for Description 371:
# ChocoDelight Dark 200g
#
# Processed Product for Description 372:
# ChocoDelight Dark 350g
#
# Processed Product for Description 373:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 374:
# DarkDream Dark 60g
#
# Processed Product for Description 375:
# MintyFresh Mint 18g
#
# Processed Product for Description 376:
# ChocoDelight Dark 200g
#
# Processed Product for Description 377:
# ChocoDelight White 350g
#
# Processed Product for Description 378:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 379:
# DarkDream Dark 60g
#
# Processed Product for Description 380:
# MintyFresh Mint 18g
#
# Processed Product for Description 381:
# ChocoDelight Dark 200g
#
# Processed Product for Description 382:
# ChocoDelight Dark 350g
#
# Processed Product for Description 383:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 384:
# DarkDream Dark 60g
#
# Processed Product for Description 385:
# MintyFresh Mint 18g
#
# Processed Product for Description 386:
# ChocoDelight Dark 200g
#
# Processed Product for Description 387:
# ChocoDelight Dark 350g
#
# Processed Product for Description 388:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 389:
# DarkDream Dark 60g
#
# Processed Product for Description 390:
# MintyFresh Mint 18g
#
# Processed Product for Description 391:
# ChocoDelight Dark 200g
#
# Processed Product for Description 392:
# ChocoDelight Dark 350g
#
# Processed Product for Description 393:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 394:
# DarkDream Dark 60g
#
# Processed Product for Description 395:
# MintyFresh Mint 18g
#
# Processed Product for Description 396:
# ChocoDelight Dark 200g
#
# Processed Product for Description 397:
# ChocoDelight Dark 350g
#
# Processed Product for Description 398:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 399:
# DarkDream Dark 60g
#
# Processed Product for Description 400:
# MintyFresh Mint 18g
#
# Processed Product for Description 401:
# ChocoDelight Dark 200g
#
# Processed Product for Description 402:
# ChocoDelight White 350g
#
# Processed Product for Description 403:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 404:
# DarkDream Dark 60g
#
# Processed Product for Description 405:
# MintyFresh Mint 18g
#
# Processed Product for Description 406:
# ChocoDelight Dark 200g
#
# Processed Product for Description 407:
# ChocoDelight White 350g
#
# Processed Product for Description 408:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 409:
# DarkDream Dark 60g
#
# Processed Product for Description 410:
# MintyFresh Mint 18g
#
# Processed Product for Description 411:
# ChocoDelight Dark 200g
#
# Processed Product for Description 412:
# ChocoDelight Dark 350g
#
# Processed Product for Description 413:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 414:
# DarkDream Dark 60g
#
# Processed Product for Description 415:
# MintyFresh Mint 18g
#
# Processed Product for Description 416:
# ChocoDelight Dark 200g
#
# Processed Product for Description 417:
# ChocoDelight 350g
#
# Processed Product for Description 418:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 419:
# DarkDream Dark 60g
#
# Processed Product for Description 420:
# MintyFresh Mint 18g
#
# Processed Product for Description 421:
# ChocoDelight Dark 200g
#
# Processed Product for Description 422:
# ChocoDelight Dark 350g
#
# Processed Product for Description 423:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 424:
# DarkDream Dark 60g
#
# Processed Product for Description 425:
# MintyFresh Mint 18g
#
# Processed Product for Description 426:
# ChocoDelight Dark 200g
#
# Processed Product for Description 427:
# ChocoDelight White 350g
#
# Processed Product for Description 428:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 429:
# DarkDream Dark 60g
#
# Processed Product for Description 430:
# MintyFresh Mint 18g
#
# Processed Product for Description 431:
# ChocoDelight Dark 200g
#
# Processed Product for Description 432:
# ChocoDelight Dark 350g
#
# Processed Product for Description 433:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 434:
# DarkDream Dark 60g
#
# Processed Product for Description 435:
# MintyFresh Mint 18g
#
# Processed Product for Description 436:
# ChocoDelight Dark 200g
#
# Processed Product for Description 437:
# ChocoDelight Dark 350g
#
# Processed Product for Description 438:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 439:
# DarkDream Dark 60g
#
# Processed Product for Description 440:
# MintyFresh Mint 18g
#
# Processed Product for Description 441:
# ChocoDelight Dark 200g
#
# Processed Product for Description 442:
# ChocoDelight Dark 350g
#
# Processed Product for Description 443:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 444:
# DarkDream Dark 60g
#
# Processed Product for Description 445:
# MintyFresh Mint 18g
#
# Processed Product for Description 446:
# ChocoDelight Dark 200g
#
# Processed Product for Description 447:
# ChocoDelight White 350g
#
# Processed Product for Description 448:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 449:
# DarkDream Dark 60g
#
# Processed Product for Description 450:
# MintyFresh Mint 18g
#
# Processed Product for Description 451:
# ChocoDelight Dark 200g
#
# Processed Product for Description 452:
# ChocoDelight 350g
#
# Processed Product for Description 453:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 454:
# DarkDream Dark 60g
#
# Processed Product for Description 455:
# MintyFresh Mint 18g
#
# Processed Product for Description 456:
# ChocoDelight Dark 200g
#
# Processed Product for Description 457:
# ChocoDelight 350g
#
# Processed Product for Description 458:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 459:
# DarkDream Dark 60g
#
# Processed Product for Description 460:
# MintyFresh Mint 18g
#
# Processed Product for Description 461:
# ChocoDelight Dark 200g
#
# Processed Product for Description 462:
# ChocoDelight Dark 350g
#
# Processed Product for Description 463:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 464:
# DarkDream Dark 60g
#
# Processed Product for Description 465:
# MintyFresh Mint 18g
#
# Processed Product for Description 466:
# ChocoDelight Dark 200g
#
# Processed Product for Description 467:
# ChocoDelight Dark 350g
#
# Processed Product for Description 468:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 469:
# DarkDream Dark 60g
#
# Processed Product for Description 470:
# MintyFresh Mint 18g
#
# Processed Product for Description 471:
# ChocoDelight Dark 200g
#
# Processed Product for Description 472:
# ChocoDelight 350g
#
# Processed Product for Description 473:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 474:
# DarkDream Dark 60g
#
# Processed Product for Description 475:
# MintyFresh Mint 18g
#
# Processed Product for Description 476:
# ChocoDelight Dark 200g
#
# Processed Product for Description 477:
# ChocoDelight White 350g
#
# Processed Product for Description 478:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 479:
# DarkDream Dark 60g
#
# Processed Product for Description 480:
# MintyFresh Mint 18g
#
# Processed Product for Description 481:
# ChocoDelight Dark 200g
#
# Processed Product for Description 482:
# ChocoDelight Dark 350g
#
# Processed Product for Description 483:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 484:
# DarkDream Dark 60g
#
# Processed Product for Description 485:
# MintyFresh Mint 18g
#
# Processed Product for Description 486:
# ChocoDelight Dark 200g
#
# Processed Product for Description 487:
# ChocoDelight White 350g
#
# Processed Product for Description 488:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 489:
# DarkDream Dark 60g
#
# Processed Product for Description 490:
# MintyFresh Mint 18g
#
# Processed Product for Description 491:
# ChocoDelight Dark 200g
#
# Processed Product for Description 492:
# ChocoDelight White 350g
#
# Processed Product for Description 493:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 494:
# DarkDream Dark 60g
#
# Processed Product for Description 495:
# MintyFresh Mint 18g
#
# Processed Product for Description 496:
# ChocoDelight Dark 200g
#
# Processed Product for Description 497:
# ChocoDelight White 350g
#
# Processed Product for Description 498:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 499:
# DarkDream Dark 60g
#
# Processed Product for Description 500:
# MintyFresh Mint 18g
#
# Processed Product for Description 501:
# ChocoDelight Dark 200g
#
# Processed Product for Description 502:
# ChocoDelight White 350g
#
# Processed Product for Description 503:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 504:
# DarkDream Dark 60g
#
# Processed Product for Description 505:
# MintyFresh Mint 18g
#
# Processed Product for Description 506:
# ChocoDelight Dark 200g
#
# Processed Product for Description 507:
# ChocoDelight 350g
#
# Processed Product for Description 508:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 509:
# DarkDream Dark 60g
#
# Processed Product for Description 510:
# MintyFresh Mint 18g
#
# Processed Product for Description 511:
# ChocoDelight Dark 200g
#
# Processed Product for Description 512:
# ChocoDelight White 350g
#
# Processed Product for Description 513:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 514:
# DarkDream Dark 60g
#
# Processed Product for Description 515:
# MintyFresh Mint 18g
#
# Processed Product for Description 516:
# ChocoDelight Dark 200g
#
# Processed Product for Description 517:
# ChocoDelight White 350g
#
# Processed Product for Description 518:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 519:
# DarkDream Dark 60g
#
# Processed Product for Description 520:
# MintyFresh Mint 18g
#
# Processed Product for Description 521:
# ChocoDelight Dark 200g
#
# Processed Product for Description 522:
# ChocoDelight White 350g
#
# Processed Product for Description 523:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 524:
# DarkDream Dark 60g
#
# Processed Product for Description 525:
# MintyFresh Mint 18g
#
# Processed Product for Description 526:
# ChocoDelight Dark 200g
#
# Processed Product for Description 527:
# ChocoDelight 350g
#
# Processed Product for Description 528:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 529:
# DarkDream Dark 60g
#
# Processed Product for Description 530:
# MintyFresh Mint 18g
#
# Processed Product for Description 531:
# ChocoDelight Dark 200g
#
# Processed Product for Description 532:
# ChocoDelight White 350g
#
# Processed Product for Description 533:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 534:
# DarkDream Dark 60g
#
# Processed Product for Description 535:
# MintyFresh Mint 18g
#
# Processed Product for Description 536:
# ChocoDelight Dark 200g
#
# Processed Product for Description 537:
# ChocoDelight 350g
#
# Processed Product for Description 538:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 539:
# DarkDream Dark 60g
#
# Processed Product for Description 540:
# MintyFresh Mint 18g
#
# Processed Product for Description 541:
# ChocoDelight Dark 200g
#
# Processed Product for Description 542:
# ChocoDelight 350g
#
# Processed Product for Description 543:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 544:
# DarkDream Dark 60g
#
# Processed Product for Description 545:
# MintyFresh Mint 18g
#
# Processed Product for Description 546:
# ChocoDelight Dark 200g
#
# Processed Product for Description 547:
# ChocoDelight Dark 350g
#
# Processed Product for Description 548:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 549:
# DarkDream Dark 60g
#
# Processed Product for Description 550:
# MintyFresh Mint 18g
#
# Processed Product for Description 551:
# ChocoDelight Dark 200g
#
# Processed Product for Description 552:
# ChocoDelight White 350g
#
# Processed Product for Description 553:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 554:
# DarkDream Dark 60g
#
# Processed Product for Description 555:
# MintyFresh Mint 18g
#
# Processed Product for Description 556:
# ChocoDelight Dark 200g
#
# Processed Product for Description 557:
# ChocoDelight Dark 350g
#
# Processed Product for Description 558:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 559:
# DarkDream Dark 60g
#
# Processed Product for Description 560:
# MintyFresh Mint 18g
#
# Processed Product for Description 561:
# ChocoDelight Dark 200g
#
# Processed Product for Description 562:
# ChocoDelight White 350g
#
# Processed Product for Description 563:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 564:
# DarkDream Dark 60g
#
# Processed Product for Description 565:
# MintyFresh Mint 18g
#
# Processed Product for Description 566:
# ChocoDelight Dark 200g
#
# Processed Product for Description 567:
# ChocoDelight 350g
#
# Processed Product for Description 568:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 569:
# DarkDream Dark 60g
#
# Processed Product for Description 570:
# MintyFresh Mint 18g
#
# Processed Product for Description 571:
# ChocoDelight Dark 200g
#
# Processed Product for Description 572:
# ChocoDelight 350g
#
# Processed Product for Description 573:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 574:
# DarkDream Dark 60g
#
# Processed Product for Description 575:
# MintyFresh Mint 18g
#
# Processed Product for Description 576:
# ChocoDelight Dark 200g
#
# Processed Product for Description 577:
# ChocoDelight White 350g
#
# Processed Product for Description 578:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 579:
# DarkDream Dark 60g
#
# Processed Product for Description 580:
# MintyFresh Mint 18g
#
# Processed Product for Description 581:
# ChocoDelight Dark 200g
#
# Processed Product for Description 582:
# ChocoDelight Dark 350g
#
# Processed Product for Description 583:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 584:
# DarkDream Dark 60g
#
# Processed Product for Description 585:
# MintyFresh Mint 18g
#
# Processed Product for Description 586:
# ChocoDelight Dark 200g
#
# Processed Product for Description 587:
# ChocoDelight 350g
#
# Processed Product for Description 588:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 589:
# DarkDream Dark 60g
#
# Processed Product for Description 590:
# MintyFresh Mint 18g
#
# Processed Product for Description 591:
# ChocoDelight Dark 200g
#
# Processed Product for Description 592:
# ChocoDelight White 350g
#
# Processed Product for Description 593:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 594:
# DarkDream Dark 60g
#
# Processed Product for Description 595:
# MintyFresh Mint 18g
#
# Processed Product for Description 596:
# ChocoDelight Dark 200g
#
# Processed Product for Description 597:
# ChocoDelight 350g
#
# Processed Product for Description 598:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 599:
# DarkDream Dark 60g
#
# Processed Product for Description 600:
# MintyFresh Mint 18g
#
# Processed Product for Description 601:
# ChocoDelight Dark 200g
#
# Processed Product for Description 602:
# ChocoDelight White 350g
#
# Processed Product for Description 603:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 604:
# DarkDream Dark 60g
#
# Processed Product for Description 605:
# MintyFresh Mint 18g
#
# Processed Product for Description 606:
# ChocoDelight Dark 200g
#
# Processed Product for Description 607:
# ChocoDelight Dark 350g
#
# Processed Product for Description 608:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 609:
# DarkDream Dark 60g
#
# Processed Product for Description 610:
# MintyFresh Mint 18g
#
# Processed Product for Description 611:
# ChocoDelight Dark 200g
#
# Processed Product for Description 612:
# ChocoDelight White 350g
#
# Processed Product for Description 613:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 614:
# DarkDream Dark 60g
#
# Processed Product for Description 615:
# MintyFresh Mint 18g
#
# Processed Product for Description 616:
# ChocoDelight Dark 200g
#
# Processed Product for Description 617:
# ChocoDelight Dark 350g
#
# Processed Product for Description 618:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 619:
# DarkDream Dark 60g
#
# Processed Product for Description 620:
# MintyFresh Mint 18g
#
# Processed Product for Description 621:
# ChocoDelight Dark 200g
#
# Processed Product for Description 622:
# ChocoDelight Dark 350g
#
# Processed Product for Description 623:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 624:
# DarkDream Dark 60g
#
# Processed Product for Description 625:
# MintyFresh Mint 18g
#
# Processed Product for Description 626:
# ChocoDelight Dark 200g
#
# Processed Product for Description 627:
# ChocoDelight White 350g
#
# Processed Product for Description 628:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 629:
# DarkDream Dark 60g
#
# Processed Product for Description 630:
# MintyFresh Mint 18g
#
# Processed Product for Description 631:
# ChocoDelight Dark 200g
#
# Processed Product for Description 632:
# ChocoDelight White 350g
#
# Processed Product for Description 633:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 634:
# DarkDream Dark 60g
#
# Processed Product for Description 635:
# MintyFresh Mint 18g
#
# Processed Product for Description 636:
# ChocoDelight Dark 200g
#
# Processed Product for Description 637:
# ChocoDelight White 350g
#
# Processed Product for Description 638:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 639:
# DarkDream Dark 60g
#
# Processed Product for Description 640:
# MintyFresh Mint 18g
#
# Processed Product for Description 641:
# ChocoDelight Dark 200g
#
# Processed Product for Description 642:
# ChocoDelight White 350g
#
# Processed Product for Description 643:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 644:
# DarkDream Dark 60g
#
# Processed Product for Description 645:
# MintyFresh Mint 18g
#
# Processed Product for Description 646:
# ChocoDelight Dark 200g
#
# Processed Product for Description 647:
# ChocoDelight Dark 350g
#
# Processed Product for Description 648:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 649:
# DarkDream Dark 60g
#
# Processed Product for Description 650:
# MintyFresh Mint 18g
#
# Processed Product for Description 651:
# ChocoDelight Dark 200g
#
# Processed Product for Description 652:
# ChocoDelight 350g
#
# Processed Product for Description 653:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 654:
# DarkDream Dark 60g
#
# Processed Product for Description 655:
# MintyFresh Mint 18g
#
# Processed Product for Description 656:
# ChocoDelight Dark 200g
#
# Processed Product for Description 657:
# ChocoDelight Dark 350g
#
# Processed Product for Description 658:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 659:
# DarkDream Dark 60g
#
# Processed Product for Description 660:
# MintyFresh Mint 18g
#
# Processed Product for Description 661:
# ChocoDelight Dark 200g
#
# Processed Product for Description 662:
# ChocoDelight 350g
#
# Processed Product for Description 663:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 664:
# DarkDream Dark 60g
#
# Processed Product for Description 665:
# MintyFresh Mint 18g
#
# Processed Product for Description 666:
# ChocoDelight Dark 200g
#
# Processed Product for Description 667:
# ChocoDelight 350g
#
# Processed Product for Description 668:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 669:
# DarkDream Dark 60g
#
# Processed Product for Description 670:
# MintyFresh Mint 18g
#
# Processed Product for Description 671:
# ChocoDelight Dark 200g
#
# Processed Product for Description 672:
# ChocoDelight White 350g
#
# Processed Product for Description 673:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 674:
# DarkDream Dark 60g
#
# Processed Product for Description 675:
# MintyFresh Mint 18g
#
# Processed Product for Description 676:
# ChocoDelight Dark 200g
#
# Processed Product for Description 677:
# ChocoDelight White 350g
#
# Processed Product for Description 678:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 679:
# DarkDream Dark 60g
#
# Processed Product for Description 680:
# MintyFresh Mint 18g
#
# Processed Product for Description 681:
# ChocoDelight Dark 200g
#
# Processed Product for Description 682:
# ChocoDelight Dark 350g
#
# Processed Product for Description 683:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 684:
# DarkDream Dark 60g
#
# Processed Product for Description 685:
# MintyFresh Mint 18g
#
# Processed Product for Description 686:
# ChocoDelight Dark 200g
#
# Processed Product for Description 687:
# ChocoDelight White 350g
#
# Processed Product for Description 688:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 689:
# DarkDream Dark 60g
#
# Processed Product for Description 690:
# MintyFresh Mint 18g
#
# Processed Product for Description 691:
# ChocoDelight Dark 200g
#
# Processed Product for Description 692:
# ChocoDelight White 350g
#
# Processed Product for Description 693:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 694:
# DarkDream Dark 60g
#
# Processed Product for Description 695:
# MintyFresh Mint 18g
#
# Processed Product for Description 696:
# ChocoDelight Dark 200g
#
# Processed Product for Description 697:
# ChocoDelight 350g
#
# Processed Product for Description 698:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 699:
# DarkDream Dark 60g
#
# Processed Product for Description 700:
# MintyFresh Mint 18g
#
# Processed Product for Description 701:
# ChocoDelight Dark 200g
#
# Processed Product for Description 702:
# ChocoDelight White 350g
#
# Processed Product for Description 703:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 704:
# DarkDream Dark 60g
#
# Processed Product for Description 705:
# MintyFresh Mint 18g
#
# Processed Product for Description 706:
# ChocoDelight Dark 200g
#
# Processed Product for Description 707:
# ChocoDelight White 350g
#
# Processed Product for Description 708:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 709:
# DarkDream Dark 60g
#
# Processed Product for Description 710:
# MintyFresh Mint 18g
#
# Processed Product for Description 711:
# ChocoDelight Dark 200g
#
# Processed Product for Description 712:
# ChocoDelight 350g
#
# Processed Product for Description 713:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 714:
# DarkDream Dark 60g
#
# Processed Product for Description 715:
# MintyFresh Mint 18g
#
# Processed Product for Description 716:
# ChocoDelight Dark 200g
#
# Processed Product for Description 717:
# ChocoDelight Dark 350g
#
# Processed Product for Description 718:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 719:
# DarkDream Dark 60g
#
# Processed Product for Description 720:
# MintyFresh Mint 18g
#
# Processed Product for Description 721:
# ChocoDelight Dark 200g
#
# Processed Product for Description 722:
# ChocoDelight Dark 350g
#
# Processed Product for Description 723:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 724:
# DarkDream Dark 60g
#
# Processed Product for Description 725:
# MintyFresh Mint 18g
#
# Processed Product for Description 726:
# ChocoDelight Dark 200g
#
# Processed Product for Description 727:
# ChocoDelight 350g
#
# Processed Product for Description 728:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 729:
# DarkDream Dark 60g
#
# Processed Product for Description 730:
# MintyFresh Mint 18g
#
# Processed Product for Description 731:
# ChocoDelight Dark 200g
#
# Processed Product for Description 732:
# ChocoDelight White 350g
#
# Processed Product for Description 733:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 734:
# DarkDream Dark 60g
#
# Processed Product for Description 735:
# MintyFresh Mint 18g
#
# Processed Product for Description 736:
# ChocoDelight Dark 200g
#
# Processed Product for Description 737:
# ChocoDelight Dark 350g
#
# Processed Product for Description 738:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 739:
# DarkDream Dark 60g
#
# Processed Product for Description 740:
# MintyFresh Mint 18g
#
# Processed Product for Description 741:
# ChocoDelight Dark 200g
#
# Processed Product for Description 742:
# ChocoDelight Dark 350g
#
# Processed Product for Description 743:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 744:
# DarkDream Dark 60g
#
# Processed Product for Description 745:
# MintyFresh Mint 18g
#
# Processed Product for Description 746:
# ChocoDelight Dark 200g
#
# Processed Product for Description 747:
# ChocoDelight White 350g
#
# Processed Product for Description 748:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 749:
# DarkDream Dark 60g
#
# Processed Product for Description 750:
# MintyFresh Mint 18g
#
# Processed Product for Description 751:
# ChocoDelight Dark 200g
#
# Processed Product for Description 752:
# ChocoDelight White 350g
#
# Processed Product for Description 753:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 754:
# DarkDream Dark 60g
#
# Processed Product for Description 755:
# MintyFresh Mint 18g
#
# Processed Product for Description 756:
# ChocoDelight Dark 200g
#
# Processed Product for Description 757:
# ChocoDelight White 350g
#
# Processed Product for Description 758:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 759:
# DarkDream Dark 60g
#
# Processed Product for Description 760:
# MintyFresh Mint 18g
#
# Processed Product for Description 761:
# ChocoDelight Dark 200g
#
# Processed Product for Description 762:
# ChocoDelight White 350g
#
# Processed Product for Description 763:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 764:
# DarkDream Dark 60g
#
# Processed Product for Description 765:
# MintyFresh Mint 18g
#
# Processed Product for Description 766:
# ChocoDelight Dark 200g
#
# Processed Product for Description 767:
# ChocoDelight Dark 350g
#
# Processed Product for Description 768:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 769:
# DarkDream Dark 60g
#
# Processed Product for Description 770:
# MintyFresh Mint 18g
#
# Processed Product for Description 771:
# ChocoDelight Dark 200g
#
# Processed Product for Description 772:
# ChocoDelight Dark 350g
#
# Processed Product for Description 773:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 774:
# DarkDream Dark 60g
#
# Processed Product for Description 775:
# MintyFresh Mint 18g
#
# Processed Product for Description 776:
# ChocoDelight Dark 200g
#
# Processed Product for Description 777:
# ChocoDelight White 350g
#
# Processed Product for Description 778:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 779:
# DarkDream Dark 60g
#
# Processed Product for Description 780:
# MintyFresh Mint 18g
#
# Processed Product for Description 781:
# ChocoDelight Dark 200g
#
# Processed Product for Description 782:
# ChocoDelight 350g
#
# Processed Product for Description 783:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 784:
# DarkDream Dark 60g
#
# Processed Product for Description 785:
# MintyFresh Mint 18g
#
# Processed Product for Description 786:
# ChocoDelight Dark 200g
#
# Processed Product for Description 787:
# ChocoDelight 350g
#
# Processed Product for Description 788:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 789:
# DarkDream Dark 60g
#
# Processed Product for Description 790:
# MintyFresh Mint 18g
#
# Processed Product for Description 791:
# ChocoDelight Dark 200g
#
# Processed Product for Description 792:
# ChocoDelight 350g
#
# Processed Product for Description 793:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 794:
# DarkDream Dark 60g
#
# Processed Product for Description 795:
# MintyFresh Mint 18g
#
# Processed Product for Description 796:
# ChocoDelight Dark 200g
#
# Processed Product for Description 797:
# ChocoDelight Dark 350g
#
# Processed Product for Description 798:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 799:
# DarkDream Dark 60g
#
# Processed Product for Description 800:
# MintyFresh Mint 18g
#
# Processed Product for Description 801:
# ChocoDelight Dark 200g
#
# Processed Product for Description 802:
# ChocoDelight White 350g
#
# Processed Product for Description 803:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 804:
# DarkDream Dark 60g
#
# Processed Product for Description 805:
# MintyFresh Mint 18g
#
# Processed Product for Description 806:
# ChocoDelight Dark 200g
#
# Processed Product for Description 807:
# ChocoDelight Dark 350g
#
# Processed Product for Description 808:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 809:
# DarkDream Dark 60g
#
# Processed Product for Description 810:
# MintyFresh Mint 18g
#
# Processed Product for Description 811:
# ChocoDelight Dark 200g
#
# Processed Product for Description 812:
# ChocoDelight 350g
#
# Processed Product for Description 813:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 814:
# DarkDream Dark 60g
#
# Processed Product for Description 815:
# MintyFresh Mint 18g
#
# Processed Product for Description 816:
# ChocoDelight Dark 200g
#
# Processed Product for Description 817:
# ChocoDelight White 350g
#
# Processed Product for Description 818:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 819:
# DarkDream Dark 60g
#
# Processed Product for Description 820:
# MintyFresh Mint 18g
#
# Processed Product for Description 821:
# ChocoDelight Dark 200g
#
# Processed Product for Description 822:
# ChocoDelight Dark 350g
#
# Processed Product for Description 823:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 824:
# DarkDream Dark 60g
#
# Processed Product for Description 825:
# MintyFresh Mint 18g
#
# Processed Product for Description 826:
# ChocoDelight Dark 200g
#
# Processed Product for Description 827:
# ChocoDelight White 350g
#
# Processed Product for Description 828:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 829:
# DarkDream Dark 60g
#
# Processed Product for Description 830:
# MintyFresh Mint 18g
#
# Processed Product for Description 831:
# ChocoDelight Dark 200g
#
# Processed Product for Description 832:
# ChocoDelight Dark 350g
#
# Processed Product for Description 833:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 834:
# DarkDream Dark 60g
#
# Processed Product for Description 835:
# MintyFresh Mint 18g
#
# Processed Product for Description 836:
# ChocoDelight Dark 200g
#
# Processed Product for Description 837:
# ChocoDelight White 350g
#
# Processed Product for Description 838:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 839:
# DarkDream Dark 60g
#
# Processed Product for Description 840:
# MintyFresh Mint 18g
#
# Processed Product for Description 841:
# ChocoDelight Dark 200g
#
# Processed Product for Description 842:
# ChocoDelight White 350g
#
# Processed Product for Description 843:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 844:
# DarkDream Dark 60g
#
# Processed Product for Description 845:
# MintyFresh Mint 18g
#
# Processed Product for Description 846:
# ChocoDelight Dark 200g
#
# Processed Product for Description 847:
# ChocoDelight Dark 350g
#
# Processed Product for Description 848:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 849:
# DarkDream Dark 60g
#
# Processed Product for Description 850:
# MintyFresh Mint 18g
#
# Processed Product for Description 851:
# ChocoDelight Dark 200g
#
# Processed Product for Description 852:
# ChocoDelight Dark 350g
#
# Processed Product for Description 853:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 854:
# DarkDream Dark 60g
#
# Processed Product for Description 855:
# MintyFresh Mint 18g
#
# Processed Product for Description 856:
# ChocoDelight Dark 200g
#
# Processed Product for Description 857:
# ChocoDelight White 350g
#
# Processed Product for Description 858:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 859:
# DarkDream Dark 60g
#
# Processed Product for Description 860:
# MintyFresh Mint 18g
#
# Processed Product for Description 861:
# ChocoDelight Dark 200g
#
# Processed Product for Description 862:
# ChocoDelight White 350g
#
# Processed Product for Description 863:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 864:
# DarkDream Dark 60g
#
# Processed Product for Description 865:
# MintyFresh Mint 18g
#
# Processed Product for Description 866:
# ChocoDelight Dark 200g
#
# Processed Product for Description 867:
# ChocoDelight Dark 350g
#
# Processed Product for Description 868:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 869:
# DarkDream Dark 60g
#
# Processed Product for Description 870:
# MintyFresh Mint 18g
#
# Processed Product for Description 871:
# ChocoDelight Dark 200g
#
# Processed Product for Description 872:
# ChocoDelight 350g
#
# Processed Product for Description 873:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 874:
# DarkDream Dark 60g
#
# Processed Product for Description 875:
# MintyFresh Mint 18g
#
# Processed Product for Description 876:
# ChocoDelight Dark 200g
#
# Processed Product for Description 877:
# ChocoDelight 350g
#
# Processed Product for Description 878:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 879:
# DarkDream Dark 60g
#
# Processed Product for Description 880:
# MintyFresh Mint 18g
#
# Processed Product for Description 881:
# ChocoDelight Dark 200g
#
# Processed Product for Description 882:
# ChocoDelight 350g
#
# Processed Product for Description 883:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 884:
# DarkDream Dark 60g
#
# Processed Product for Description 885:
# MintyFresh Mint 18g
#
# Processed Product for Description 886:
# ChocoDelight Dark 200g
#
# Processed Product for Description 887:
# ChocoDelight Dark 350g
#
# Processed Product for Description 888:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 889:
# DarkDream Dark 60g
#
# Processed Product for Description 890:
# MintyFresh Mint 18g
#
# Processed Product for Description 891:
# ChocoDelight Dark 200g
#
# Processed Product for Description 892:
# ChocoDelight White 350g
#
# Processed Product for Description 893:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 894:
# DarkDream Dark 60g
#
# Processed Product for Description 895:
# MintyFresh Mint 18g
#
# Processed Product for Description 896:
# ChocoDelight Dark 200g
#
# Processed Product for Description 897:
# ChocoDelight Dark 350g
#
# Processed Product for Description 898:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 899:
# DarkDream Dark 60g
#
# Processed Product for Description 900:
# MintyFresh Mint 18g
#
# Processed Product for Description 901:
# ChocoDelight Dark 200g
#
# Processed Product for Description 902:
# ChocoDelight White 350g
#
# Processed Product for Description 903:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 904:
# DarkDream Dark 60g
#
# Processed Product for Description 905:
# MintyFresh Mint 18g
#
# Processed Product for Description 906:
# ChocoDelight Dark 200g
#
# Processed Product for Description 907:
# ChocoDelight 350g
#
# Processed Product for Description 908:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 909:
# DarkDream Dark 60g
#
# Processed Product for Description 910:
# MintyFresh Mint 18g
#
# Processed Product for Description 911:
# ChocoDelight Dark 200g
#
# Processed Product for Description 912:
# ChocoDelight 350g
#
# Processed Product for Description 913:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 914:
# DarkDream Dark 60g
#
# Processed Product for Description 915:
# MintyFresh Mint 18g
#
# Processed Product for Description 916:
# ChocoDelight Dark 200g
#
# Processed Product for Description 917:
# ChocoDelight White 350g
#
# Processed Product for Description 918:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 919:
# DarkDream Dark 60g
#
# Processed Product for Description 920:
# MintyFresh Mint 18g
#
# Processed Product for Description 921:
# ChocoDelight Dark 200g
#
# Processed Product for Description 922:
# ChocoDelight 350g
#
# Processed Product for Description 923:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 924:
# DarkDream Dark 60g
#
# Processed Product for Description 925:
# MintyFresh Mint 18g
#
# Processed Product for Description 926:
# ChocoDelight Dark 200g
#
# Processed Product for Description 927:
# ChocoDelight White 350g
#
# Processed Product for Description 928:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 929:
# DarkDream Dark 60g
#
# Processed Product for Description 930:
# MintyFresh Mint 18g
#
# Processed Product for Description 931:
# ChocoDelight Dark 200g
#
# Processed Product for Description 932:
# ChocoDelight White 350g
#
# Processed Product for Description 933:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 934:
# DarkDream Dark 60g
#
# Processed Product for Description 935:
# MintyFresh Mint 18g
#
# Processed Product for Description 936:
# ChocoDelight Dark 200g
#
# Processed Product for Description 937:
# ChocoDelight 350g
#
# Processed Product for Description 938:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 939:
# DarkDream Dark 60g
#
# Processed Product for Description 940:
# MintyFresh Mint 18g
#
# Processed Product for Description 941:
# ChocoDelight Dark 200g
#
# Processed Product for Description 942:
# ChocoDelight White 350g
#
# Processed Product for Description 943:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 944:
# DarkDream Dark 60g
#
# Processed Product for Description 945:
# MintyFresh Mint 18g
#
# Processed Product for Description 946:
# ChocoDelight Dark 200g
#
# Processed Product for Description 947:
# ChocoDelight White 350g
#
# Processed Product for Description 948:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 949:
# DarkDream Dark 60g
#
# Processed Product for Description 950:
# MintyFresh Mint 18g
#
# Processed Product for Description 951:
# ChocoDelight Dark 200g
#
# Processed Product for Description 952:
# ChocoDelight White 350g
#
# Processed Product for Description 953:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 954:
# DarkDream Dark 60g
#
# Processed Product for Description 955:
# MintyFresh Mint 18g
#
# Processed Product for Description 956:
# ChocoDelight Dark 200g
#
# Processed Product for Description 957:
# ChocoDelight White 350g
#
# Processed Product for Description 958:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 959:
# DarkDream Dark 60g
#
# Processed Product for Description 960:
# MintyFresh Mint 18g
#
# Processed Product for Description 961:
# ChocoDelight Dark 200g
#
# Processed Product for Description 962:
# ChocoDelight 350g
#
# Processed Product for Description 963:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 964:
# DarkDream Dark 60g
#
# Processed Product for Description 965:
# MintyFresh Mint 18g
#
# Processed Product for Description 966:
# ChocoDelight Dark 200g
#
# Processed Product for Description 967:
# ChocoDelight White 350g
#
# Processed Product for Description 968:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 969:
# DarkDream Dark 60g
#
# Processed Product for Description 970:
# MintyFresh Mint 18g
#
# Processed Product for Description 971:
# ChocoDelight Dark 200g
#
# Processed Product for Description 972:
# ChocoDelight Dark 350g
#
# Processed Product for Description 973:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 974:
# DarkDream Dark 60g
#
# Processed Product for Description 975:
# MintyFresh Mint 18g
#
# Processed Product for Description 976:
# ChocoDelight Dark 200g
#
# Processed Product for Description 977:
# ChocoDelight Dark 350g
#
# Processed Product for Description 978:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 979:
# DarkDream Dark 60g
#
# Processed Product for Description 980:
# MintyFresh Mint 18g
#
# Processed Product for Description 981:
# ChocoDelight Dark 200g
#
# Processed Product for Description 982:
# ChocoDelight White 350g
#
# Processed Product for Description 983:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 984:
# DarkDream Dark 60g
#
# Processed Product for Description 985:
# MintyFresh Mint 18g
#
# Processed Product for Description 986:
# ChocoDelight Dark 200g
#
# Processed Product for Description 987:
# ChocoDelight White 350g
#
# Processed Product for Description 988:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 989:
# DarkDream Dark 60g
#
# Processed Product for Description 990:
# MintyFresh Mint 18g
#
# Processed Product for Description 991:
# ChocoDelight Dark 200g
#
# Processed Product for Description 992:
# ChocoDelight White 350g
#
# Processed Product for Description 993:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 994:
# DarkDream Dark 60g
#
# Processed Product for Description 995:
# MintyFresh Mint 18g
#
# Processed Product for Description 996:
# ChocoDelight Dark 200g
#
# Processed Product for Description 997:
# ChocoDelight 350g
#
# Processed Product for Description 998:
# NuttyCream Hazelnuts 80g
#
# Processed Product for Description 999:
# DarkDream Dark 60g
#
#                                          description                   Product
# 0                    MintyFresh refresh mint 18grams       MintyFresh Mint 18g
# 1                           200g ChocoDelight smooth    ChocoDelight Dark 200g
# 2                        350g ChocoDelight delicious    ChocoDelight Dark 350g
# 3                delightful Hazelnuts 80g NuttyCream  NuttyCream Hazelnuts 80g
# 4  A decadent DarkDream dark chocolate ice cream ...        DarkDream Dark 60g

# %%
print(extracted_info_df.head())
# Out:
#                                          description                   Product
# 0                    MintyFresh refresh mint 18grams       MintyFresh Mint 18g
# 1                           200g ChocoDelight smooth    ChocoDelight Dark 200g
# 2                        350g ChocoDelight delicious    ChocoDelight Dark 350g
# 3                delightful Hazelnuts 80g NuttyCream  NuttyCream Hazelnuts 80g
# 4  A decadent DarkDream dark chocolate ice cream ...        DarkDream Dark 60g

# %%
import pandas as pd



# Save extracted product information to CSV
output_path = '../../data/processed/extracted_product_info.csv'
extracted_info_df.to_csv(output_path, index=False)
print(f"Extracted product information saved to {output_path}")

# Load the original data for comparison
original_df = pd.read_csv('../../data/raw/Retail_Sales_Data.csv')

# Take only the first 1000 rows to match the extracted data
original_df_1000 = original_df.head(1000)

# Merge the original and extracted DataFrames to facilitate comparison
comparison_df = original_df_1000[['product']].reset_index(drop=True).copy()
comparison_df['Extracted_Product'] = extracted_info_df['Product']

# Check accuracy by comparing original and extracted product names
comparison_df['Match'] = comparison_df['product'] == comparison_df['Extracted_Product']

# Calculate accuracy
accuracy = comparison_df['Match'].mean() * 100
print(f"Accuracy of extracted product names: {accuracy:.2f}%")

# Display a sample of mismatches for review
mismatches = comparison_df[~comparison_df['Match']]
print("Sample mismatches:")
print(mismatches.head(10))
# Out:
# Extracted product information saved to ../../data/processed/extracted_product_info.csv
# Accuracy of extracted product names: 88.80%
# Sample mismatches:
#                     product       Extracted_Product  Match
# 2   ChocoDelight White 350g  ChocoDelight Dark 350g  False
# 12  ChocoDelight White 350g       ChocoDelight 350g  False
# 17  ChocoDelight White 350g  ChocoDelight Dark 350g  False
# 22  ChocoDelight White 350g  ChocoDelight Dark 350g  False
# 32  ChocoDelight White 350g       ChocoDelight 350g  False
# 42  ChocoDelight White 350g  ChocoDelight Dark 350g  False
# 57  ChocoDelight White 350g  ChocoDelight Dark 350g  False
# 77  ChocoDelight White 350g       ChocoDelight 350g  False
# 82  ChocoDelight White 350g       ChocoDelight 350g  False
# 92  ChocoDelight White 350g       ChocoDelight 350g  False

# %%
# Create a subset of the data to work with indices from 10 to 1000
comparison_df = product_info_df[['description', 'product']].copy()
comparison_df['Extracted_Product'] = extracted_info_df['Product']  # Ensure alignment with the extracted info

# Filter only the rows between index 10 and 1000
comparison_df = comparison_df.iloc[10:1000].copy()  # .iloc includes 10 and excludes 1001

# Add a Match column to indicate if the extracted product matches the original
comparison_df['Match'] = comparison_df['product'] == comparison_df['Extracted_Product']

# Filter the DataFrame to show only mismatches within the specified range
mismatches_df = comparison_df[comparison_df['Match'] == False]

# Display mismatches
print("Mismatched entries between index 10 and 1000:")
display(mismatches_df)
# Out:
# Mismatched entries between index 10 and 1000:
#                      description                  product  \
# 12      creamy ChocoDelight 350g  ChocoDelight White 350g
# 17   350g ChocoDelight delicious  ChocoDelight White 350g
# 22   350g ChocoDelight delicious  ChocoDelight White 350g
# 32      creamy ChocoDelight 350g  ChocoDelight White 350g
# 42   350g ChocoDelight delicious  ChocoDelight White 350g
# ..                           ...                      ...
# 937     creamy ChocoDelight 350g  ChocoDelight White 350g
# 962     creamy ChocoDelight 350g  ChocoDelight White 350g
# 972  350g ChocoDelight delicious  ChocoDelight White 350g
# 977  350g ChocoDelight delicious  ChocoDelight White 350g
# 997     creamy ChocoDelight 350g  ChocoDelight White 350g
#
#           Extracted_Product  Match
# 12        ChocoDelight 350g  False
# 17   ChocoDelight Dark 350g  False
# 22   ChocoDelight Dark 350g  False
# 32        ChocoDelight 350g  False
# 42   ChocoDelight Dark 350g  False
# ..                      ...    ...
# 937       ChocoDelight 350g  False
# 962       ChocoDelight 350g  False
# 972  ChocoDelight Dark 350g  False
# 977  ChocoDelight Dark 350g  False
# 997       ChocoDelight 350g  False
#
# [111 rows x 4 columns]

# %%
# Filter mismatches within the specified range
mismatches_df = comparison_df[comparison_df['Match'] == False]

# Count unique mismatched extracted products
unique_mis_extracted = mismatches_df['Extracted_Product'].value_counts()

# Display the unique mis-extracted products and their counts
print("Unique mis-extracted products and their counts:")
print(unique_mis_extracted)
# Out:
# Unique mis-extracted products and their counts:
# ChocoDelight Dark 350g    56
# ChocoDelight 350g         55
# Name: Extracted_Product, dtype: int64

# %%
# Filter to get correctly matched rows
correct_matches = comparison_df[comparison_df['Match'] == True]

# Count the unique correctly extracted products
unique_correct_counts = correct_matches['Extracted_Product'].value_counts()

# Display the unique correctly extracted products and their counts
print("Unique correctly extracted products and their counts:")
print(unique_correct_counts)
# Out:
# Unique correctly extracted products and their counts:
# MintyFresh Mint 18g         198
# ChocoDelight Dark 200g      198
# NuttyCream Hazelnuts 80g    198
# DarkDream Dark 60g          198
# ChocoDelight White 350g      87
# Name: Extracted_Product, dtype: int64

# %% [markdown]
# ### SpaCy and RegEx Example

# %%
import spacy

# Load spaCy's pre-trained NER model
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import spacy
#       3 # Load spaCy's pre-trained NER model
#       4 nlp = spacy.load("en_core_web_sm")
#
# ModuleNotFoundError: No module named 'spacy'

# %%
from collections import Counter
import spacy

# Load spaCy's pre-trained model
nlp = spacy.load("en_core_web_sm")

# List to store all adjectives that could be colors
potential_colors = []

# Loop through descriptions to identify color-like adjectives
for description in df['description']:
    doc = nlp(description)
    for token in doc:
        if token.pos_ == "ADJ":  # Look for adjectives
            potential_colors.append(token.text.lower())

# Count the frequency of each adjective to identify common colors
color_counts = Counter(potential_colors)
print("Most common potential colors:", color_counts.most_common(20))
# Out:
# Most common potential colors: [('decadent', 1346), ('rich', 1333), ('creamy', 1329), ('delightful', 1313), ('dark', 894), ('delicious', 448), ('white', 448), ('smooth', 440)]

# %%
import spacy
import re

# Load spaCy's pre-trained model
nlp = spacy.load("en_core_web_sm")

# Known brands list (add more as needed)
known_brands = ["MintyFresh", "ChocoDelight", "NuttyCream", "DarkDream"]

def extract_product_info(description):
    doc = nlp(description)
    
    brand = None
    weight = None
    descriptors = []

    # Extract brand using NER and known brands list as fallback
    for ent in doc.ents:
        if ent.label_ == "ORG" and ent.text in known_brands:
            brand = ent.text
            break

    if not brand:
        brand = next((b for b in known_brands if b in description), None)
    
    # Enhanced Weight Extraction to include variations
    weight_match = re.search(r'\b(\d+)\s*(g|gram|grams|kg|ml)\b', description, re.IGNORECASE)
    if weight_match:
        weight, unit = weight_match.groups()
        weight = int(weight)
        if unit.lower() in ['kg', 'kilogram', 'kilograms']:
            weight *= 1000  # Convert to grams

    # Collect multiple adjectives
    for token in doc:
        if token.pos_ == "ADJ" or token.dep_ == "amod":  # Capture descriptive adjectives
            descriptors.append(token.text.lower())

    # Sort descriptors for consistent ordering
    descriptors = sorted(descriptors)

    return pd.Series([brand, weight, descriptors])

# Apply the function to extract information
df[['brand', 'weight', 'descriptors']] = df['description'].apply(extract_product_info)

# Review the results
print(df[['description', 'brand', 'weight', 'descriptors']].sample(10))
# Out:
#                                             description         brand  weight  \
# 158                     80g NuttyCream flavor Hazelnuts    NuttyCream    80.0
# 5142                     ChocoDelight White 350g creamy  ChocoDelight   350.0
# 1792  A creamy and delicious ChocoDelight white choc...  ChocoDelight   350.0
# 3156                           200g ChocoDelight smooth  ChocoDelight   200.0
# 639                         Dark DarkDream 60g decadent     DarkDream    60.0
# 1192                     ChocoDelight White 350g creamy  ChocoDelight   350.0
# 3530                    MintyFresh refresh mint 18grams    MintyFresh    18.0
# 1250  A refreshing MintyFresh candy with a weight of...    MintyFresh     NaN
# 5456                             rich ChocoDelight 200g  ChocoDelight   200.0
# 2184  A decadent DarkDream dark chocolate ice cream ...     DarkDream    60.0
#
#                      descriptors
# 158                           []
# 5142                    [creamy]
# 1792  [creamy, delicious, white]
# 3156                          []
# 639                   [decadent]
# 1192                    [creamy]
# 3530                          []
# 1250                [refreshing]
# 5456                      [rich]
# 2184            [dark, decadent]

# %%
print(df[['description', 'brand', 'weight', 'descriptors']].sample(10))
# Out:
#                                             description         brand  weight  \
# 3039                                 60g Dark DarkDream     DarkDream    60.0
# 7676  A rich and smooth ChocoDelight dark chocolate ...  ChocoDelight   200.0
# 787                            creamy ChocoDelight 350g  ChocoDelight   350.0
# 4879                        Dark DarkDream 60g decadent     DarkDream    60.0
# 4552                           creamy ChocoDelight 350g  ChocoDelight   350.0
# 3227                     ChocoDelight White 350g creamy  ChocoDelight   350.0
# 2096                        ChocoDelight Dark 200g rich  ChocoDelight   200.0
# 2413                delightful Hazelnuts 80g NuttyCream    NuttyCream    80.0
# 6950                    MintyFresh refresh mint 18grams    MintyFresh    18.0
# 1753                    80g NuttyCream flavor Hazelnuts    NuttyCream    80.0
#
#                descriptors
# 3039                    []
# 7676  [dark, rich, smooth]
# 787               [creamy]
# 4879            [decadent]
# 4552              [creamy]
# 3227              [creamy]
# 2096                [rich]
# 2413          [delightful]
# 6950                    []
# 1753                    []

# %%
# Out:
#                                             description         brand  weight
# 1807                        350g ChocoDelight delicious  ChocoDelight   350.0
# 755                              MintyFresh 18g refresh    MintyFresh    18.0
# 801                            200g ChocoDelight smooth  ChocoDelight   200.0
# 120                              MintyFresh 18g refresh    MintyFresh    18.0
# 168                Hazelnuts NuttyCream 80g  delightful    NuttyCream    80.0
# 1606                           200g ChocoDelight smooth  ChocoDelight   200.0
# 776                            200g ChocoDelight smooth  ChocoDelight   200.0
# 4365                             MintyFresh 18g refresh    MintyFresh    18.0
# 3981                             rich ChocoDelight 200g  ChocoDelight   200.0
# 6179  A decadent DarkDream dark chocolate ice cream ...     DarkDream    60.0

# %%
# Review unique brands
print("Unique brands:", df['brand'].unique())

# Review unique weights
print("Unique weights:", df['weight'].unique())
# Out:
# Unique brands: ['MintyFresh' 'ChocoDelight' 'NuttyCream' 'DarkDream']
# Unique weights: [ 18. 200. 350.  80.  60.  nan]

# %%
# Flag unusual weights
invalid_weights = df[(df['weight'] < 1) | (df['weight'] > 5000)]
print("Rows with unusual weights:")
print(invalid_weights[['description', 'brand', 'weight']])

# Check for rare brands that might be extraction errors
brand_counts = df['brand'].value_counts()
rare_brands = brand_counts[brand_counts < 3].index
print("Rare brands that might be errors:", rare_brands)

# Filter rows with rare brands for review
print(df[df['brand'].isin(rare_brands)][['description', 'brand', 'weight']])
# Out:
# Rows with unusual weights:
# Empty DataFrame
# Columns: [description, brand, weight]
# Index: []
# Rare brands that might be errors: Index([], dtype='object', name='brand')
# Empty DataFrame
# Columns: [description, brand, weight]
# Index: []

# %%
# Convert `brand` to categorical numbers
df['brand_category'] = pd.factorize(df['brand'])[0]

# Convert `descriptors` list to a unique string for factorization
df['descriptors_str'] = df['descriptors'].apply(lambda x: ', '.join(x) if x else None)
df['descriptors_category'] = pd.factorize(df['descriptors_str'])[0]

# Drop the intermediate `descriptors_str` and the original `brand` and `descriptors` columns
df.drop(columns=['descriptors_str', 'brand', 'descriptors'], inplace=True)

# Review the result
print(df.head(10))
# Out:
#   retailer  store_id  week                   product  regular_price     value  \
# 0  retail1         1     1       MintyFresh Mint 18g      10.308645  4.458621
# 1  retail1         1     1    ChocoDelight Dark 200g       7.947956  4.429920
# 2  retail1         1     1   ChocoDelight White 350g      13.439368  3.980200
# 3  retail1         1     1  NuttyCream Hazelnuts 80g       5.112777  3.899420
# 4  retail1         1     1        DarkDream Dark 60g      14.085425  3.886054
# 5  retail1         1     2       MintyFresh Mint 18g      16.415525  4.260473
# 6  retail1         1     2    ChocoDelight Dark 200g      13.768042  4.007392
# 7  retail1         1     2   ChocoDelight White 350g       9.337017  4.316094
# 8  retail1         1     2  NuttyCream Hazelnuts 80g      17.867154  4.089784
# 9  retail1         1     2        DarkDream Dark 60g      18.006656  4.408259
#
#      volume  quantity  competition_1_discount_depth  \
# 0  3.953882  2.370986                      5.168518
# 1  2.991418  2.767739                      2.058444
# 2  6.513600  2.631141                      4.620759
# 3  5.489587  2.732732                      0.000000
# 4  9.152050  2.321781                      0.000000
# 5  7.465654  2.500194                      0.000000
# 6  1.880907  2.207793                      0.000000
# 7  6.809493  2.256616                      0.000000
# 8  7.318122  2.205286                      7.049807
# 9  6.809740  2.337996                      0.000000
#
#    competition_2_discount_depth  ...  price_comp_8_promo_interaction  \
# 0                      3.058420  ...                        1.434868
# 1                      1.008545  ...                        1.139282
# 2                      2.718872  ...                        1.228372
# 3                      0.000000  ...                        0.000000
# 4                      0.000000  ...                        0.000000
# 5                      0.000000  ...                        0.000000
# 6                      0.000000  ...                        0.000000
# 7                      0.000000  ...                        0.000000
# 8                      6.598379  ...                        1.276868
# 9                      0.000000  ...                        0.000000
#
#    price_comp_9_promo_interaction  price_comp_10_promo_interaction  \
# 0                        1.789813                         1.397488
# 1                        1.350594                         1.489539
# 2                        1.539970                         1.697930
# 3                        0.000000                         0.000000
# 4                        0.000000                         0.000000
# 5                        0.000000                         0.000000
# 6                        0.000000                         0.000000
# 7                        0.000000                         0.000000
# 8                        2.080890                         1.504928
# 9                        0.000000                         0.000000
#
#    quantity_lag_1  value_lag_1  sin_week  cos_week  weight  brand_category  \
# 0        0.000000     0.000000  0.120537  0.992709    18.0               0
# 1        2.370986     4.458621  0.120537  0.992709   200.0               1
# 2        2.767739     4.429920  0.120537  0.992709   350.0               1
# 3        2.631141     3.980200  0.120537  0.992709    80.0               2
# 4        2.732732     3.899420  0.120537  0.992709    60.0               3
# 5        2.321781     3.886054  0.239316  0.970942    18.0               0
# 6        2.500194     4.260473  0.239316  0.970942   200.0               1
# 7        2.207793     4.007392  0.239316  0.970942   350.0               1
# 8        2.256616     4.316094  0.239316  0.970942    80.0               2
# 9        2.205286     4.089784  0.239316  0.970942    60.0               3
#
#    descriptors_category
# 0                    -1
# 1                    -1
# 2                    -1
# 3                     0
# 4                     1
# 5                    -1
# 6                     2
# 7                     3
# 8                     0
# 9                     1
#
# [10 rows x 37 columns]

# %%
# Export the DataFrame to a CSV with a unique name to avoid overwriting
df.to_csv('../../data/processed/processed_data_with_features.csv', index=False)

# %%
import pandas as pd

# Load the processed data with spaCy features
df_spacy = pd.read_csv('../../data/processed/processed_data_with_features.csv')

# Check if the relevant columns (e.g., 'brand', 'weight', 'flavor/type') exist
if all(col in df_spacy.columns for col in ['brand', 'weight', 'flavor']):
    # Construct the product name by combining 'brand', 'flavor', and 'weight'
    df_spacy['Reconstructed_Product'] = df_spacy['brand'] + ' ' + df_spacy['flavor'] + ' ' + df_spacy['weight']
else:
    raise KeyError("Columns 'brand', 'weight', or 'flavor' are missing in the loaded DataFrame.")

# Load original dataset with product names for comparison
df_original = pd.read_csv('../../data/raw/Retail_Sales_Data.csv')[['description', 'product']]

# Merge both dataframes on the common index for comparison
df_comparison = df_original[['product']].copy()
df_comparison['Extracted_Product'] = df_spacy['Reconstructed_Product']

# Add a column to indicate if the extracted product matches the original
df_comparison['Match'] = df_comparison['product'] == df_comparison['Extracted_Product']

# Calculate the accuracy
accuracy = df_comparison['Match'].mean() * 100

# Display the accuracy and sample mismatches
print(f"Accuracy of spaCy-extracted product names: {accuracy:.2f}%")

# Display sample mismatches if any
mismatches = df_comparison[df_comparison['Match'] == False][['product', 'Extracted_Product']]
print("Sample mismatches between original and spaCy-extracted product names:")
print(mismatches.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 11
#       9     df_spacy['Reconstructed_Product'] = df_spacy['brand'] + ' ' + df_spacy['flavor'] + ' ' + df_spacy['weight']
#      10 else:
# ---> 11     raise KeyError("Columns 'brand', 'weight', or 'flavor' are missing in the loaded DataFrame.")
#      13 # Load original dataset with product names for comparison
#      14 df_original = pd.read_csv('../../data/raw/Retail_Sales_Data.csv')[['description', 'product']]
#
# KeyError: "Columns 'brand', 'weight', or 'flavor' are missing in the loaded DataFrame."
